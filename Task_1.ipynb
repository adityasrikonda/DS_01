# %% [markdown]
# <a href="https://colab.research.google.com/github/adityasrikonda/DS_01/blob/main/Task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir("/content/drive/MyDrive/Projects")

# %%
# !pip install xlrd
import pandas as pd
df = pd.read_excel("/content/drive/MyDrive/Projects/API_SP.POP.TOTL_DS2_en_excel_v2_9.xls")

# %%
df.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2024-12-16 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#           Unnamed: 2      Unnamed: 3   Unnamed: 4   Unnamed: 5   Unnamed: 6  \
# 0                NaN             NaN          NaN          NaN          NaN
# 1                NaN             NaN          NaN          NaN          NaN
# 2     Indicator Name  Indicator Code       1960.0       1961.0       1962.0
# 3  Population, total     SP.POP.TOTL      54922.0      55578.0      56320.0
# 4  Population, total     SP.POP.TOTL  130072080.0  133534923.0  137171659.0
#
#     Unnamed: 7   Unnamed: 8   Unnamed: 9  ...  Unnamed: 58  Unnamed: 59  \
# ...

# %%
df.describe()
# Out:
#          Unnamed: 4    Unnamed: 5    Unnamed: 6    Unnamed: 7    Unnamed: 8  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   1.150126e+08  1.166123e+08  1.187664e+08  1.214281e+08  1.241137e+08
# std    3.620343e+08  3.665406e+08  3.731936e+08  3.818093e+08  3.904733e+08
# min    1.960000e+03  1.961000e+03  1.962000e+03  1.963000e+03  1.964000e+03
# 25%    5.123160e+05  5.182660e+05  5.246490e+05  5.314520e+05  5.386570e+05
# 50%    3.645600e+06  3.715534e+06  3.806307e+06  3.900506e+06  3.997305e+06
# 75%    2.685175e+07  2.760090e+07  2.833701e+07  2.909187e+07  2.985892e+07
# max    3.021529e+09  3.062769e+09  3.117373e+09  3.184063e+09  3.251253e+09
#
#          Unnamed: 9   Unnamed: 10   Unnamed: 11   Unnamed: 12   Unnamed: 13  \
# count  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02  2.650000e+02
# mean   1.268310e+08  1.296672e+08  1.325111e+08  1.354298e+08  1.384464e+08
# ...

# %%
df.shape
# Out:
# (269, 68)

# %%
df.isnull().sum()
# Out:
# Data Source                     1
# World Development Indicators    1
# Unnamed: 2                      2
# Unnamed: 3                      2
# Unnamed: 4                      4
#                                ..
# Unnamed: 63                     3
# Unnamed: 64                     3
# Unnamed: 65                     3
# Unnamed: 66                     3
# Unnamed: 67                     3
# Length: 68, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 228

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 68 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Data Source                   268 non-null    object
#  1   World Development Indicators  268 non-null    object
#  2   Unnamed: 2                    267 non-null    object
#  3   Unnamed: 3                    267 non-null    object
#  4   Unnamed: 4                    265 non-null    float64
#  5   Unnamed: 5                    265 non-null    float64
#  6   Unnamed: 6                    265 non-null    float64
#  7   Unnamed: 7                    265 non-null    float64
#  8   Unnamed: 8                    265 non-null    float64
#  9   Unnamed: 9                    265 non-null    float64
#  10  Unnamed: 10                   265 non-null    float64
#  11  Unnamed: 11                   265 non-null    float64
# ...

# %%
df['Data Source'].fillna(df['Data Source'].mode()[0], inplace=True)
df['Unnamed: 2'].fillna(df['Unnamed: 2'].mode()[0], inplace=True)               # Fill 'budget' column with its most frequent value
df['Unnamed: 3'].fillna(df['Unnamed: 3'].mode()[0], inplace=True)
df['Unnamed: 4'].fillna(df['Unnamed: 4'].mode()[0], inplace=True)
df['Unnamed: 5'].fillna(df['Unnamed: 5'].mode()[0], inplace=True)
df['Unnamed: 6'].fillna(df['Unnamed: 6'].mode()[0], inplace=True)
df['Unnamed: 7'].fillna(df['Unnamed: 7'].mode()[0], inplace=True)
df['Unnamed: 8'].fillna(df['Unnamed: 8'].mode()[0], inplace=True)
df['Unnamed: 9'].fillna(df['Unnamed: 9'].mode()[0], inplace=True)
df['Unnamed: 10'].fillna(df['Unnamed: 10'].mode()[0], inplace=True)
df['Unnamed: 11'].fillna(df['Unnamed: 11'].mode()[0], inplace=True)
df['Unnamed: 12'].fillna(df['Unnamed: 12'].mode()[0], inplace=True)
df['Unnamed: 13'].fillna(df['Unnamed: 13'].mode()[0], inplace=True)
df['Unnamed: 14'].fillna(df['Unnamed: 14'].mode()[0], inplace=True)
df['Unnamed: 15'].fillna(df['Unnamed: 15'].mode()[0], inplace=True)
df['Unnamed: 16'].fillna(df['Unnamed: 16'].mode()[0], inplace=True)
df['Unnamed: 17'].fillna(df['Unnamed: 17'].mode()[0], inplace=True)
df['Unnamed: 18'].fillna(df['Unnamed: 18'].mode()[0], inplace=True)
df['Unnamed: 19'].fillna(df['Unnamed: 19'].mode()[0], inplace=True)
df['Unnamed: 20'].fillna(df['Unnamed: 20'].mode()[0], inplace=True)
df['Unnamed: 21'].fillna(df['Unnamed: 21'].mode()[0], inplace=True)
df['Unnamed: 22'].fillna(df['Unnamed: 22'].mode()[0], inplace=True)
df['Unnamed: 23'].fillna(df['Unnamed: 23'].mode()[0], inplace=True)
df['Unnamed: 24'].fillna(df['Unnamed: 24'].mode()[0], inplace=True)
df['Unnamed: 25'].fillna(df['Unnamed: 25'].mode()[0], inplace=True)
df['Unnamed: 26'].fillna(df['Unnamed: 26'].mode()[0], inplace=True)
df['Unnamed: 27'].fillna(df['Unnamed: 27'].mode()[0], inplace=True)
df['Unnamed: 28'].fillna(df['Unnamed: 28'].mode()[0], inplace=True)
df['Unnamed: 29'].fillna(df['Unnamed: 29'].mode()[0], inplace=True)
df['Unnamed: 30'].fillna(df['Unnamed: 30'].mode()[0], inplace=True)
df['Unnamed: 31'].fillna(df['Unnamed: 31'].mode()[0], inplace=True)
df['Unnamed: 32'].fillna(df['Unnamed: 32'].mode()[0], inplace=True)
df['Unnamed: 33'].fillna(df['Unnamed: 33'].mode()[0], inplace=True)
df['Unnamed: 34'].fillna(df['Unnamed: 34'].mode()[0], inplace=True)
df['Unnamed: 35'].fillna(df['Unnamed: 35'].mode()[0], inplace=True)
df['Unnamed: 36'].fillna(df['Unnamed: 36'].mode()[0], inplace=True)
df['Unnamed: 37'].fillna(df['Unnamed: 37'].mode()[0], inplace=True)
df['Unnamed: 38'].fillna(df['Unnamed: 38'].mode()[0], inplace=True)
df['Unnamed: 39'].fillna(df['Unnamed: 39'].mode()[0], inplace=True)
df['Unnamed: 40'].fillna(df['Unnamed: 40'].mode()[0], inplace=True)
df['Unnamed: 41'].fillna(df['Unnamed: 41'].mode()[0], inplace=True)
df['Unnamed: 42'].fillna(df['Unnamed: 42'].mode()[0], inplace=True)
df['Unnamed: 43'].fillna(df['Unnamed: 43'].mode()[0], inplace=True)
df['Unnamed: 44'].fillna(df['Unnamed: 44'].mode()[0], inplace=True)
df['Unnamed: 45'].fillna(df['Unnamed: 45'].mode()[0], inplace=True)
df['Unnamed: 46'].fillna(df['Unnamed: 46'].mode()[0], inplace=True)
df['Unnamed: 47'].fillna(df['Unnamed: 47'].mode()[0], inplace=True)
df['Unnamed: 48'].fillna(df['Unnamed: 48'].mode()[0], inplace=True)
df['Unnamed: 49'].fillna(df['Unnamed: 49'].mode()[0], inplace=True)
df['Unnamed: 50'].fillna(df['Unnamed: 50'].mode()[0], inplace=True)
df['Unnamed: 51'].fillna(df['Unnamed: 51'].mode()[0], inplace=True)
df['Unnamed: 52'].fillna(df['Unnamed: 52'].mode()[0], inplace=True)
df['Unnamed: 53'].fillna(df['Unnamed: 53'].mode()[0], inplace=True)
df['Unnamed: 54'].fillna(df['Unnamed: 54'].mode()[0], inplace=True)
df['Unnamed: 55'].fillna(df['Unnamed: 55'].mode()[0], inplace=True)
df['Unnamed: 56'].fillna(df['Unnamed: 56'].mode()[0], inplace=True)
df['Unnamed: 57'].fillna(df['Unnamed: 57'].mode()[0], inplace=True)
df['Unnamed: 58'].fillna(df['Unnamed: 58'].mode()[0], inplace=True)
df['Unnamed: 59'].fillna(df['Unnamed: 59'].mode()[0], inplace=True)
df['Unnamed: 60'].fillna(df['Unnamed: 60'].mode()[0], inplace=True)
df['Unnamed: 61'].fillna(df['Unnamed: 61'].mode()[0], inplace=True)
df['Unnamed: 62'].fillna(df['Unnamed: 62'].mode()[0], inplace=True)
df['Unnamed: 63'].fillna(df['Unnamed: 63'].mode()[0], inplace=True)
df['Unnamed: 64'].fillna(df['Unnamed: 64'].mode()[0], inplace=True)
df['Unnamed: 65'].fillna(df['Unnamed: 65'].mode()[0], inplace=True)
df['Unnamed: 66'].fillna(df['Unnamed: 66'].mode()[0], inplace=True)
df['Unnamed: 67'].fillna(df['Unnamed: 67'].mode()[0], inplace=True)
# Out:
# <ipython-input-15-1e5374bb1ca0>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Data Source'].fillna(df['Data Source'].mode()[0], inplace=True)
# <ipython-input-15-1e5374bb1ca0>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.isnull().sum().sum()
# Out:
# 1

# %%
import matplotlib.pyplot as plt # Import the pyplot module as plt
import matplotlib.pyplot as plt # Import the pyplot module as plt

plt.title("Population Comparison by Year and Country (1960-2023)", fontsize=14)
plt.hist('Population')
plt.xlabel("Data Source", fontsize=12)
plt.ylabel("Unnamed: 4", fontsize=12)
plt.legend(title="Country", fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.legend(title="Country", fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
# Out:
# <ipython-input-18-9cf55ef9080a>:8: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Country", fontsize=10)
# <ipython-input-18-9cf55ef9080a>:11: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="Country", fontsize=10)
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2]),
#  [Text(0, 0.0, '0.0'),
#   Text(0, 0.2, '0.2'),
#   Text(0, 0.4, '0.4'),
#   Text(0, 0.6000000000000001, '0.6'),
#   Text(0, 0.8, '0.8'),
#   Text(0, 1.0, '1.0'),
#   Text(0, 1.2000000000000002, '1.2')])

# %%
import matplotlib.pyplot as plt # Import the pyplot module as plt

plt.title("Population Comparison by Year and Country (2020-2023)", fontsize=14)
plt.xlabel("Country Name", fontsize=12)
plt.ylabel("Year 1960", fontsize=12)
plt.legend(title="Country", fontsize=10)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
